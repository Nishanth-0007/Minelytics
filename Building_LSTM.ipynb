# %% [markdown]
# ## Building LSTM

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# Load dataset
df = pd.read_csv("highrange_25yrs_indian_coalmine_data.csv")

# Emission factors
CO2_PER_LITER_DIESEL = 2.68      # kg CO₂ per liter diesel
CO2_PER_TONNE_COAL = 1.9         # kg CO₂ per tonne coal mined

# ✅ Calculate CO₂ emissions directly from fuel + coal
df["CO2_Emitted_kg"] = (
    df["Fuel_Used_Liters"] * CO2_PER_LITER_DIESEL +
    df["Coal_Mined_Tonnes"] * CO2_PER_TONNE_COAL
)

# Features & target
features = df[["Fuel_Used_Liters", "Coal_Mined_Tonnes"]].values
target = df["CO2_Emitted_kg"].values.reshape(-1, 1)

# Scaling
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_x.fit_transform(features)
y_scaled = scaler_y.fit_transform(target)

# Save scalers
joblib.dump(scaler_x, "scaler_x.pkl")
joblib.dump(scaler_y, "scaler_y.pkl")

# Create sequences
TIME_STEPS = 14

def create_sequences(X, y, time_steps=14):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i + time_steps])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y_scaled)
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, shuffle=False)

# Build LSTM model with Dropout
input_layer = Input(shape=(TIME_STEPS, 2))
x = LSTM(128, return_sequences=True)(input_layer)
x = Dropout(0.2)(x)
x = LSTM(64, return_sequences=True)(x)
x = Dropout(0.2)(x)
x = LSTM(32)(x)
x = Dense(32, activation='relu')(x)
output = Dense(1)(x)

model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Early stopping to prevent overtraining
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train
model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

# Save final model
model.save("lstm_co2_predictor.h5")
print("✅ Improved LSTM model trained and saved successfully!")
# Out:
# Epoch 1/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - loss: 0.0370 - mae: 0.1300 - val_loss: 0.0055 - val_mae: 0.0606
# Epoch 2/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0062 - mae: 0.0633 - val_loss: 0.0063 - val_mae: 0.0645
# Epoch 3/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0060 - mae: 0.0620 - val_loss: 0.0047 - val_mae: 0.0558
# Epoch 4/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0053 - mae: 0.0585 - val_loss: 0.0045 - val_mae: 0.0545
# Epoch 5/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0050 - mae: 0.0565 - val_loss: 0.0047 - val_mae: 0.0559
# Epoch 6/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - loss: 0.0050 - mae: 0.0562 - val_loss: 0.0047 - val_mae: 0.0555
# Epoch 7/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 0.0049 - mae: 0.0560 - val_loss: 0.0046 - val_mae: 0.0553
# Epoch 8/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0048 - mae: 0.0551 - val_loss: 0.0050 - val_mae: 0.0566
# Epoch 9/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0047 - mae: 0.0546 - val_loss: 0.0045 - val_mae: 0.0547
# Epoch 10/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0047 - mae: 0.0545 - val_loss: 0.0044 - val_mae: 0.0537
# Epoch 11/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 0.0048 - mae: 0.0548 - val_loss: 0.0045 - val_mae: 0.0542
# Epoch 12/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0047 - mae: 0.0546 - val_loss: 0.0051 - val_mae: 0.0575
# Epoch 13/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0046 - mae: 0.0539 - val_loss: 0.0043 - val_mae: 0.0530
# Epoch 14/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0044 - mae: 0.0528 - val_loss: 0.0045 - val_mae: 0.0545
# Epoch 15/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 0.0045 - mae: 0.0532 - val_loss: 0.0044 - val_mae: 0.0539
# Epoch 16/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0047 - mae: 0.0548 - val_loss: 0.0044 - val_mae: 0.0539
# Epoch 17/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0046 - mae: 0.0539 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 18/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0044 - mae: 0.0529 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 19/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 0.0044 - mae: 0.0528 - val_loss: 0.0045 - val_mae: 0.0546
# Epoch 20/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0046 - mae: 0.0539 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 21/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0044 - mae: 0.0528 - val_loss: 0.0042 - val_mae: 0.0525
# Epoch 22/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0044 - mae: 0.0528 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 23/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0044 - mae: 0.0531 - val_loss: 0.0042 - val_mae: 0.0525
# Epoch 24/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0044 - mae: 0.0530 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 25/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0044 - mae: 0.0527 - val_loss: 0.0042 - val_mae: 0.0525
# Epoch 26/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0044 - mae: 0.0531 - val_loss: 0.0043 - val_mae: 0.0535
# Epoch 27/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0045 - mae: 0.0531 - val_loss: 0.0045 - val_mae: 0.0546
# Epoch 28/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0044 - mae: 0.0529 - val_loss: 0.0043 - val_mae: 0.0529
# Epoch 29/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0043 - mae: 0.0520 - val_loss: 0.0045 - val_mae: 0.0547
# Epoch 30/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0045 - mae: 0.0537 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 31/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0045 - mae: 0.0535 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 32/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0043 - mae: 0.0524 - val_loss: 0.0042 - val_mae: 0.0524
# Epoch 33/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0043 - mae: 0.0524 - val_loss: 0.0042 - val_mae: 0.0520
# Epoch 34/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 0.0043 - mae: 0.0522 - val_loss: 0.0041 - val_mae: 0.0518
# Epoch 35/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 0.0044 - mae: 0.0529 - val_loss: 0.0046 - val_mae: 0.0552
# Epoch 36/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0045 - mae: 0.0533 - val_loss: 0.0043 - val_mae: 0.0530
# Epoch 37/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0044 - mae: 0.0527 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 38/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 0.0043 - mae: 0.0519 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 39/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0043 - mae: 0.0518 - val_loss: 0.0042 - val_mae: 0.0520
# Epoch 40/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0041 - mae: 0.0508 - val_loss: 0.0042 - val_mae: 0.0526
# Epoch 41/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0042 - mae: 0.0511 - val_loss: 0.0042 - val_mae: 0.0525
# Epoch 42/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0042 - mae: 0.0518 - val_loss: 0.0050 - val_mae: 0.0570
# Epoch 43/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0045 - mae: 0.0536 - val_loss: 0.0042 - val_mae: 0.0519
# Epoch 44/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0043 - mae: 0.0520 - val_loss: 0.0042 - val_mae: 0.0522
# Epoch 45/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0045 - mae: 0.0532 - val_loss: 0.0045 - val_mae: 0.0540
# Epoch 46/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0043 - mae: 0.0519 - val_loss: 0.0042 - val_mae: 0.0522
# Epoch 47/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0045 - mae: 0.0526 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 48/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0042 - mae: 0.0522 - val_loss: 0.0043 - val_mae: 0.0528
# Epoch 49/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0043 - mae: 0.0524 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 50/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0044 - mae: 0.0527 - val_loss: 0.0047 - val_mae: 0.0555
# Epoch 51/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0043 - mae: 0.0522 - val_loss: 0.0041 - val_mae: 0.0517
# Epoch 52/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.0044 - mae: 0.0528 - val_loss: 0.0051 - val_mae: 0.0578
# Epoch 53/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0043 - mae: 0.0523 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 54/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0044 - mae: 0.0526 - val_loss: 0.0044 - val_mae: 0.0532
# Epoch 55/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0043 - mae: 0.0519 - val_loss: 0.0044 - val_mae: 0.0537
# Epoch 56/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0044 - mae: 0.0529 - val_loss: 0.0041 - val_mae: 0.0517
# Epoch 57/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0042 - mae: 0.0513 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 58/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0043 - mae: 0.0519 - val_loss: 0.0046 - val_mae: 0.0544
# Epoch 59/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0045 - mae: 0.0529 - val_loss: 0.0043 - val_mae: 0.0527
# Epoch 60/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0043 - mae: 0.0523 - val_loss: 0.0042 - val_mae: 0.0521
# Epoch 61/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0043 - mae: 0.0523 - val_loss: 0.0041 - val_mae: 0.0516
# Epoch 62/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - loss: 0.0044 - mae: 0.0533 - val_loss: 0.0044 - val_mae: 0.0533
# Epoch 63/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - loss: 0.0042 - mae: 0.0515 - val_loss: 0.0047 - val_mae: 0.0551
# Epoch 64/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - loss: 0.0043 - mae: 0.0522 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 65/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0044 - mae: 0.0530 - val_loss: 0.0046 - val_mae: 0.0541
# Epoch 66/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - loss: 0.0044 - mae: 0.0523 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 67/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0044 - mae: 0.0534 - val_loss: 0.0044 - val_mae: 0.0534
# Epoch 68/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0043 - mae: 0.0522 - val_loss: 0.0043 - val_mae: 0.0524
# Epoch 69/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - loss: 0.0041 - mae: 0.0514 - val_loss: 0.0043 - val_mae: 0.0525
# Epoch 70/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0041 - mae: 0.0510 - val_loss: 0.0043 - val_mae: 0.0530
# Epoch 71/300
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - loss: 0.0042 - mae: 0.0518 - val_loss: 0.0042 - val_mae: 0.0521
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Improved LSTM model trained and saved successfully!

# %%
model.save("lstm_co2_predictor.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 6.89%
